# %%
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
feature_vectors = pd.read_csv("biophony-3D.csv")
labels_true = feature_vectors["class"]
feature_vectors = feature_vectors.drop(columns=["class"])
feature_vectors = feature_vectors.iloc[:, 0:13].values
labels_true
# Out:
# 0       biophony
# 1       biophony
# 2       biophony
# 3       biophony
# 4       biophony
#           ...
# 3277    biophony
# 3278    biophony
# 3279    biophony
# 3280    biophony
# 3281    biophony
# Name: class, Length: 3282, dtype: object

# %%
kmeans_data_old = pd.read_csv('kmeans_results.csv')

#encoding class values
kmeans_data_old['class'] = kmeans_data_old['class'].str.replace('other', str(0))
kmeans_data_old['class'] = kmeans_data_old['class'].str.replace('biophony', str(1))
kmeans_data_old['class'] = kmeans_data_old['class'].str.replace('geophony', str(2))
kmeans_data_old['class'] = kmeans_data_old['class'].str.replace('anthrophony', str(3))

y_km = kmeans_data_old['class']
# y_km.drop(y_km.tail(1).index, inplace=True)
y_km = y_km.values
y_km
# Out:
# array(['3', '3', '3', ..., '0', '0', '0'], dtype=object)

# %%
model = TSNE(n_components=3, learning_rate=150, perplexity=50, verbose=2, angle=0.1, random_state=0).fit_transform(feature_vectors)
# Out:
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\manifold\_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 3282 samples in 0.003s...
# [t-SNE] Computed neighbors for 3282 samples in 0.114s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3282
# [t-SNE] Computed conditional probabilities for sample 2000 / 3282
# [t-SNE] Computed conditional probabilities for sample 3000 / 3282
# [t-SNE] Computed conditional probabilities for sample 3282 / 3282
# [t-SNE] Mean sigma: 0.110222
# [t-SNE] Computed conditional probabilities in 0.071s
# [t-SNE] Iteration 50: error = 71.5771408, gradient norm = 0.0333639 (50 iterations in 0.859s)
# [t-SNE] Iteration 100: error = 65.0879440, gradient norm = 0.0030740 (50 iterations in 0.542s)
# [t-SNE] Iteration 150: error = 64.6194763, gradient norm = 0.0010648 (50 iterations in 0.521s)
# [t-SNE] Iteration 200: error = 64.4714508, gradient norm = 0.0006791 (50 iterations in 0.513s)
# [t-SNE] Iteration 250: error = 64.3973770, gradient norm = 0.0004940 (50 iterations in 0.512s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 64.397377
# [t-SNE] Iteration 300: error = 1.3254198, gradient norm = 0.0008021 (50 iterations in 0.843s)
# [t-SNE] Iteration 350: error = 1.0955026, gradient norm = 0.0002108 (50 iterations in 1.016s)
# [t-SNE] Iteration 400: error = 1.0087216, gradient norm = 0.0000869 (50 iterations in 1.035s)
# [t-SNE] Iteration 450: error = 0.9657295, gradient norm = 0.0000549 (50 iterations in 0.995s)
# [t-SNE] Iteration 500: error = 0.9404723, gradient norm = 0.0000339 (50 iterations in 1.137s)
# [t-SNE] Iteration 550: error = 0.9242270, gradient norm = 0.0000317 (50 iterations in 1.020s)
# [t-SNE] Iteration 600: error = 0.9129606, gradient norm = 0.0000207 (50 iterations in 0.962s)
# [t-SNE] Iteration 650: error = 0.9046541, gradient norm = 0.0000193 (50 iterations in 0.958s)
# [t-SNE] Iteration 700: error = 0.8971572, gradient norm = 0.0000365 (50 iterations in 0.986s)
# [t-SNE] Iteration 750: error = 0.8933460, gradient norm = 0.0000168 (50 iterations in 0.987s)
# [t-SNE] Iteration 800: error = 0.8896582, gradient norm = 0.0000601 (50 iterations in 1.047s)
# [t-SNE] Iteration 850: error = 0.8872340, gradient norm = 0.0000125 (50 iterations in 0.981s)
# [t-SNE] Iteration 900: error = 0.8850275, gradient norm = 0.0000121 (50 iterations in 0.957s)
# [t-SNE] Iteration 950: error = 0.8832378, gradient norm = 0.0000086 (50 iterations in 0.963s)
# [t-SNE] Iteration 1000: error = 0.8816104, gradient norm = 0.0000050 (50 iterations in 0.942s)
# [t-SNE] KL divergence after 1000 iterations: 0.881610

# %%
import numpy as np
np.savetxt("biophony-sound-3d.csv", model, delimiter=",", header="x,y,z")

# %%
colors = ['r', 'g', 'b', 'y']
y_int = [int(label) for label in y_km]
# Create 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(model[:, 0], model[:, 1], model[:, 2], c=[colors[label] for label in y_int])

# Set the viewing angle of the plot
ax.view_init(elev=20, azim=35)

# Allow interactive rotation of the plot
ax.set_box_aspect([1,1,1])
ax.mouse_init()

# Show plot
plt.title("3D t-SNE graph with ground truth values overlayed")
plt.show()

# %% [markdown]
# Silhouette analysis for 3 tsne components (8 is the best average)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score, silhouette_samples

X = feature_vectors
# Define the range of cluster numbers to evaluate
min_clusters = 2
max_clusters = 12

# Initialize variables to store best cluster number and best silhouette score
best_n_clusters = None
best_score = -1

# Iterate over different cluster numbers and compute silhouette scores and plots
for n_clusters in range(min_clusters, max_clusters+1):
    # Fit KMeans clustering model with n_clusters
    kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(X)
    # Compute silhouette scores and plot
    fig, ax = plt.subplots()
    ax.set_xlim([-0.1, 1])
    ax.set_ylim([0, len(X) + (n_clusters + 1) * 10])
    silhouette_scores = silhouette_samples(X, kmeans.labels_)
    y_lower = 10
    for i in range(n_clusters):
        cluster_scores = silhouette_scores[kmeans.labels_ == i]
        cluster_scores.sort()
        size_cluster_i = len(cluster_scores)
        y_upper = y_lower + size_cluster_i
        color = plt.cm.nipy_spectral(float(i) / n_clusters)
        ax.fill_betweenx(np.arange(y_lower, y_upper), 0, cluster_scores, facecolor=color, alpha=0.7)
        ax.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
        y_lower = y_upper + 10
    ax.set_title("Silhouette plot for KMeans clustering with {} clusters".format(n_clusters))
    ax.set_xlabel("Silhouette coefficient values")
    ax.set_ylabel("Cluster labels")
    ax.axvline(x=silhouette_score(X, kmeans.labels_, metric='euclidean'), color="red", linestyle="--")
    ax.set_yticks([])
    plt.show()
# Out:
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Initialize an empty list to store SSE values
sse = []

# Fit KMeans algorithm on the dataset for k values from 1 to 10
for k in range(1, 12):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(model)
    sse.append(kmeans.inertia_)

# Plot SSE against k
sns.set_style("whitegrid")
plt.plot(range(1, 12), sse)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.show()
# Out:
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(

# %%
import pandas as pd # dataframe manipulation
import numpy as np # linear algebra

# data visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# sklearn kmeans
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import contingency_matrix

# pyclustering kmeans
from pyclustering.cluster.kmeans import kmeans
from pyclustering.utils.metric import distance_metric
from pyclustering.cluster.center_initializer import random_center_initializer
from pyclustering.cluster.encoder import type_encoding
from pyclustering.cluster.encoder import cluster_encoder

from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_distances
from sklearn.metrics import adjusted_rand_score
from sklearn import metrics

# %%
from sklearn.cluster import AgglomerativeClustering

single_linkage = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='average')
labels_pred = single_linkage.fit_predict(feature_vectors)
labels = single_linkage.labels_

# %%
def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    confusion_matrix = contingency_matrix(y_true, y_pred)
    # return purity
    return np.sum(np.amax(confusion_matrix, axis=0)) / np.sum(confusion_matrix)

# %%
print(purity_score(labels_true, labels_pred))
# Out:
# 0.36023622047244097

# %%
metrics.rand_score(labels_true, labels_pred)
# Out:
# 0.3200823772539564

# %%
metrics.adjusted_rand_score(labels_true, labels_pred)
# Out:
# -0.009017571523075791

# %%
metrics.adjusted_mutual_info_score(labels_true, labels_pred)
# Out:
# 0.05760606060817765

# %%
metrics.homogeneity_score(labels_true, labels_pred)
# Out:
# 0.033191646510739733

# %%
metrics.completeness_score(labels_true, labels_pred)
# Out:
# 0.24503055962141215

# %%
metrics.v_measure_score(labels_true, labels_pred)
# Out:
# 0.05846382883916603

# %%
metrics.fowlkes_mallows_score(labels_true, labels_pred)
# Out:
# 0.5144876712137095

# %%
# from sklearn.cluster import KMeans
# km = KMeans(n_clusters=8, init='k-means++', random_state=42)
# y_km = km.fit_predict(model)
# labels = km.labels_

# %%
labels
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
colors = ['r', 'g', 'b', 'y', 'rx', 'c', 'm', 'k', 'w']
y_int = [int(label) for label in labels]
# Create 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(model[:, 0], model[:, 1], model[:, 2], c=labels, cmap='viridis')

# Set the viewing angle of the plot
ax.view_init(elev=20, azim=35)

# Allow interactive rotation of the plot
ax.set_box_aspect([1,1,1])
ax.mouse_init()

# Show plot
plt.title("3D t-SNE graph with kmeans (k=8) overlayed")
plt.show()

# %%
import pandas as pd # dataframe manipulation
import numpy as np # linear algebra

# data visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# sklearn kmeans
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import contingency_matrix

# pyclustering kmeans
from pyclustering.cluster.kmeans import kmeans
from pyclustering.utils.metric import distance_metric
from pyclustering.cluster.center_initializer import random_center_initializer
from pyclustering.cluster.encoder import type_encoding
from pyclustering.cluster.encoder import cluster_encoder

from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_distances
from sklearn.metrics import adjusted_rand_score
import numpy as np
import pandas as pd
from sklearn import metrics

# %%
def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    confusion_matrix = contingency_matrix(y_true, y_pred)
    # return purity
    return np.sum(np.amax(confusion_matrix, axis=0)) / np.sum(confusion_matrix)

# %%
# define dictionary for distance measures
distance_measures = {'euclidean': 0, 'squared euclidean': 1, 'manhattan': 2, 'chebyshev': 3, 
                    'canberra': 5, 'chi-square': 6}
X = feature_vectors
y = labels_true

# function defined to compute purity score using pyclustering for various distance measures
def pyPurity(dist_measure):
    initial_centers = random_center_initializer(X, 8, random_state=5).initialize()
    # instance created for respective distance metric
    instanceKm = kmeans(X, initial_centers=initial_centers, metric=distance_metric(dist_measure))
    # perform cluster analysis
    instanceKm.process()
    # cluster analysis results - clusters and centers
    pyClusters = instanceKm.get_clusters()
    pyCenters = instanceKm.get_centers()
    # enumerate encoding type to index labeling to get labels
    pyEncoding = instanceKm.get_cluster_encoding()
    pyEncoder = cluster_encoder(pyEncoding, pyClusters, X)
    pyLabels = pyEncoder.set_encoding(0).get_clusters()
    # function purity score is defined in previous section
    print(f"Rand-score for {dist_measure} is {round(metrics.rand_score(y, pyLabels)*100, 2)}%")
    print(f"Adj-Rand-score for {dist_measure} is {round(metrics.adjusted_rand_score(y, pyLabels)*100, 2)}%")
    print(f"Adj-Mutual-score for {dist_measure} is {round(metrics.adjusted_mutual_info_score(y, pyLabels)*100, 2)}%")
    print(f"Homogeneity-score for {dist_measure} is {round(metrics.homogeneity_score(y, pyLabels)*100, 2)}%")
    print(f"Completeness-score for {dist_measure} is {round(metrics.completeness_score(y, pyLabels)*100, 2)}%")
    print(f"V-measure-score for {dist_measure} is {round(metrics.v_measure_score(y, pyLabels)*100, 2)}%")
    print(f"Fowlkes-mallows-score for {dist_measure} is {round(metrics.fowlkes_mallows_score(y, pyLabels)*100, 2)}%")
    return purity_score(y, pyLabels)

# print results
for measure, value in distance_measures.items():
    print(f"The purity score for {measure} distance is {round(pyPurity(value)*100, 2)}%")
    print(" ")
# Out:
# Rand-score for 0 is 76.89%
# Adj-Rand-score for 0 is 36.43%
# Adj-Mutual-score for 0 is 45.32%
# Homogeneity-score for 0 is 56.57%
# Completeness-score for 0 is 37.87%
# V-measure-score for 0 is 45.37%
# Fowlkes-mallows-score for 0 is 52.0%
# The purity score for euclidean distance is 78.48%
#
# Rand-score for 1 is 76.99%
# Adj-Rand-score for 1 is 36.46%
# Adj-Mutual-score for 1 is 45.36%
# Homogeneity-score for 1 is 56.81%
# Completeness-score for 1 is 37.83%
# V-measure-score for 1 is 45.42%
# Fowlkes-mallows-score for 1 is 51.99%
# The purity score for squared euclidean distance is 78.56%
#
# Rand-score for 2 is 74.16%
# Adj-Rand-score for 2 is 30.19%
# Adj-Mutual-score for 2 is 40.36%
# Homogeneity-score for 2 is 49.81%
# Completeness-score for 2 is 34.01%
# V-measure-score for 2 is 40.42%
# Fowlkes-mallows-score for 2 is 47.28%
# The purity score for manhattan distance is 75.18%
#
# Rand-score for 3 is 74.33%
# Adj-Rand-score for 3 is 29.48%
# Adj-Mutual-score for 3 is 36.11%
# Homogeneity-score for 3 is 44.98%
# Completeness-score for 3 is 30.26%
# V-measure-score for 3 is 36.18%
# Fowlkes-mallows-score for 3 is 46.35%
# The purity score for chebyshev distance is 73.17%
#
# Rand-score for 5 is 72.69%
# Adj-Rand-score for 5 is 26.62%
# Adj-Mutual-score for 5 is 36.84%
# Homogeneity-score for 5 is 45.3%
# Completeness-score for 5 is 31.13%
# V-measure-score for 5 is 36.9%
# Fowlkes-mallows-score for 5 is 44.6%
# The purity score for canberra distance is 70.7%
#
# Rand-score for 6 is 75.9%
# Adj-Rand-score for 6 is 33.69%
# Adj-Mutual-score for 6 is 43.21%
# Homogeneity-score for 6 is 53.96%
# Completeness-score for 6 is 36.11%
# V-measure-score for 6 is 43.27%
# Fowlkes-mallows-score for 6 is 49.76%
# The purity score for chi-square distance is 77.12%

# %%
# import numpy as np

# # save the numpy array to a csv file
# np.savetxt("tsne-3d.csv", model, delimiter=",", header="1, 2, 3")

# %% [markdown]
# hybrid approach

# %%
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
feature_vectors = pd.read_csv("39-feature-vector.csv")
labels_true = feature_vectors["class"]
feature_vectors = feature_vectors.drop(columns=["class"])
feature_vectors = feature_vectors.iloc[:, 0:13].values
labels_true
# Out:
# 0       anthrophony
# 1       anthrophony
# 2       anthrophony
# 3       anthrophony
# 4       anthrophony
#            ...
# 6599          other
# 6600          other
# 6601          other
# 6602          other
# 6603          other
# Name: class, Length: 6604, dtype: object

# %%
import numpy as np
from sklearn.cluster import KMeans
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram
import matplotlib.pyplot as plt

# X = feature_vectors

# # Perform k-means clustering with k=8
# initial_centers = random_center_initializer(X, 8, random_state=5).initialize()

# kmeans = KMeans(n_clusters=8, random_state=0).fit(X)

# # Get the cluster assignments and centroids
# cluster_assignments = kmeans.labels_
# centroids = kmeans.cluster_centers_

# # Calculate the pairwise distances between the centroids
# distances = squareform(pdist(centroids, metric='cosine'))

# # Perform hierarchical clustering on the distances
# Z = linkage(distances, method='complete')

# # Merge the k-means clusters using a distance threshold
# threshold = 0.08
# merged_clusters = fcluster(Z, t=threshold, criterion='distance')

# # Map the merged cluster labels back to the original data points
# final_clusters = np.zeros_like(cluster_assignments)
# for i in range(kmeans.n_clusters):
#     final_clusters[cluster_assignments == i] = merged_clusters[i]

# %%
import numpy as np
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist, cityblock
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram
import matplotlib.pyplot as plt

X = feature_vectors

# Perform k-means clustering with k=8 and Manhattan distance metric
initial_centers = random_center_initializer(X, 8, random_state=5).initialize()

# Preprocess the data using the Manhattan distance metric
preprocessed_X = cdist(X, X, metric='cosine')

kmeans = KMeans(n_clusters=8, random_state=0).fit(preprocessed_X)

# Get the cluster assignments and centroids
cluster_assignments = kmeans.labels_
centroids = kmeans.cluster_centers_

# Calculate the pairwise distances between the centroids using cosine metric
distances = squareform(pdist(centroids, metric='cosine'))

# Perform hierarchical clustering on the distances
Z = linkage(distances, method='complete')

# Merge the k-means clusters using a distance threshold
threshold = 0.2
merged_clusters = fcluster(Z, t=threshold, criterion='distance')

# Map the merged cluster labels back to the original data points
final_clusters = np.zeros_like(cluster_assignments)
for i in range(kmeans.n_clusters):
    final_clusters[cluster_assignments == i] = merged_clusters[i] % 4
# Out:
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_12884\4128929916.py:25: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distances, method='complete')

# %%
# import numpy as np
# from sklearn.cluster import KMeans
# from pyclustering.cluster.kmeans import kmeans, kmeans_visualizer
# from pyclustering.utils.metric import distance_metric, type_metric
# from scipy.spatial.distance import pdist, squareform
# from scipy.cluster.hierarchy import linkage, fcluster, dendrogram
# import matplotlib.pyplot as plt

# X = feature_vectors
# n_clusters = 8

# # Perform k-means clustering with k=8 using a custom distance metric
# metric = distance_metric(0)

# # Create an initial cluster configuration for k-means
# initial_centers = random_center_initializer(X, n_clusters, random_state=5).initialize()

# kmeans_instance = kmeans(X, initial_centers, metric=metric)
# kmeans_instance.process()
# clusters = kmeans_instance.get_clusters()
# centroids = kmeans_instance.get_centers()

# # Assign cluster labels to the data points
# cluster_assignments = np.zeros(X.shape[0], dtype=int)
# for cluster_id, cluster in enumerate(clusters):
#     cluster_assignments[cluster] = cluster_id

# # Calculate the pairwise distances between the centroids using cosine metric
# distances = squareform(pdist(centroids, metric='euclidean'))

# # Perform hierarchical clustering on the distances
# Z = linkage(distances, method='complete')

# # Merge the k-means clusters using a distance threshold
# threshold = 0.09
# merged_clusters = fcluster(Z, t=threshold, criterion='distance')

# # Map the merged cluster labels back to the original data points
# final_clusters = np.zeros_like(cluster_assignments)
# for i in range(n_clusters):
#     final_clusters[cluster_assignments == i] = merged_clusters[i]

# %%
colors = ['r', 'g', 'b', 'y']
y_int = [int(label) for label in y_km]
# Create 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(model[:, 0], model[:, 1], model[:, 2], c=[colors[label] for label in y_int])

# Show plot
plt.title("3D t-SNE graph with ground truth values overlayed")
plt.show()

# Create a scatter plot for the unmerged data points
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(model[:, 0], model[:, 1], model[:, 2], c=cluster_assignments, cmap='viridis')
ax.set_title('Unmerged Data Points')
ax.set_xlabel('Dimension 1')
ax.set_ylabel('Dimension 2')
ax.set_zlabel('Dimension 3')
fig.colorbar(scatter)
plt.show()

# Create a scatter plot for the merged data points
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(model[:, 0], model[:, 1], model[:, 2], c=final_clusters, cmap='viridis')
ax.set_title('Merged Data Points')
ax.set_xlabel('Dimension 1')
ax.set_ylabel('Dimension 2')
ax.set_zlabel('Dimension 3')
fig.colorbar(scatter)
plt.show()

# %%
from collections import Counter

# Count the occurrences of each value
value_counts = Counter(final_clusters)

# Print the unique values and their counts
for value, count in value_counts.items():
    print(f"{value}: {count}")
# Out:
# 3: 1177
# 1: 1223
# 0: 2341
# 2: 1863

# %%
# Count the occurrences of each value
value_counts = Counter(labels_true)

# Print the unique values and their counts
for value, count in value_counts.items():
    print(f"{value}: {count}")
# Out:
# anthrophony: 532
# biophony: 2379
# geophony: 2014
# other: 1679

# %%
# Plot the dendrogram after merging
fig = plt.figure(figsize=(8, 6))
merged_dendrogram = dendrogram(Z, color_threshold=threshold)
plt.title('Dendrogram after k-means clusters')
plt.axhline(y=threshold, color='r', linestyle='--')
plt.show()

# %%
# define dictionary for distance measures
distance_measures = {'euclidean': 0, 'squared euclidean': 1, 'manhattan': 2, 'chebyshev': 3, 
                    'canberra': 5, 'chi-square': 6}
X = final_clusters
y = y_km

# function defined to compute purity score using pyclustering for various distance measures
def pyPurity(dist_measure):
    pyLabels = X
    # function purity score is defined in previous section
    print(f"Rand-score for {dist_measure} is {round(metrics.rand_score(y, pyLabels)*100, 2)}%")
    print(f"Adj-Rand-score for {dist_measure} is {round(metrics.adjusted_rand_score(y, pyLabels)*100, 2)}%")
    print(f"Adj-Mutual-score for {dist_measure} is {round(metrics.adjusted_mutual_info_score(y, pyLabels)*100, 2)}%")
    print(f"Homogeneity-score for {dist_measure} is {round(metrics.homogeneity_score(y, pyLabels)*100, 2)}%")
    print(f"Completeness-score for {dist_measure} is {round(metrics.completeness_score(y, pyLabels)*100, 2)}%")
    print(f"V-measure-score for {dist_measure} is {round(metrics.v_measure_score(y, pyLabels)*100, 2)}%")
    print(f"Fowlkes-mallows-score for {dist_measure} is {round(metrics.fowlkes_mallows_score(y, pyLabels)*100, 2)}%")
    return purity_score(y, pyLabels)

# print results
for measure, value in distance_measures.items():
    print(f"The purity score for {measure} distance is {round(pyPurity(value)*100, 2)}%")
    print(" ")
# Out:
# Rand-score for 0 is 70.53%
# Adj-Rand-score for 0 is 27.34%
# Adj-Mutual-score for 0 is 31.62%
# Homogeneity-score for 0 is 32.44%
# Completeness-score for 0 is 30.91%
# V-measure-score for 0 is 31.66%
# Fowlkes-mallows-score for 0 is 47.87%
# The purity score for euclidean distance is 62.4%
#
# Rand-score for 1 is 70.53%
# Adj-Rand-score for 1 is 27.34%
# Adj-Mutual-score for 1 is 31.62%
# Homogeneity-score for 1 is 32.44%
# Completeness-score for 1 is 30.91%
# V-measure-score for 1 is 31.66%
# Fowlkes-mallows-score for 1 is 47.87%
# The purity score for squared euclidean distance is 62.4%
#
# Rand-score for 2 is 70.53%
# Adj-Rand-score for 2 is 27.34%
# Adj-Mutual-score for 2 is 31.62%
# Homogeneity-score for 2 is 32.44%
# Completeness-score for 2 is 30.91%
# V-measure-score for 2 is 31.66%
# Fowlkes-mallows-score for 2 is 47.87%
# The purity score for manhattan distance is 62.4%
#
# Rand-score for 3 is 70.53%
# Adj-Rand-score for 3 is 27.34%
# Adj-Mutual-score for 3 is 31.62%
# Homogeneity-score for 3 is 32.44%
# Completeness-score for 3 is 30.91%
# V-measure-score for 3 is 31.66%
# Fowlkes-mallows-score for 3 is 47.87%
# The purity score for chebyshev distance is 62.4%
#
# Rand-score for 5 is 70.53%
# Adj-Rand-score for 5 is 27.34%
# Adj-Mutual-score for 5 is 31.62%
# Homogeneity-score for 5 is 32.44%
# Completeness-score for 5 is 30.91%
# V-measure-score for 5 is 31.66%
# Fowlkes-mallows-score for 5 is 47.87%
# The purity score for canberra distance is 62.4%
#
# Rand-score for 6 is 70.53%
# Adj-Rand-score for 6 is 27.34%
# Adj-Mutual-score for 6 is 31.62%
# Homogeneity-score for 6 is 32.44%
# Completeness-score for 6 is 30.91%
# V-measure-score for 6 is 31.66%
# Fowlkes-mallows-score for 6 is 47.87%
# The purity score for chi-square distance is 62.4%

# %%
import numpy as np
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram
import matplotlib.pyplot as plt

# Example data points
X = feature_vectors

# Perform agglomerative hierarchical clustering
Z = linkage(X, method='complete')

# Define the distance threshold for merging clusters
threshold = 1.5  # Example threshold value, adjust as needed

# Merge the clusters based on the distance threshold
merged_clusters = fcluster(Z, t=threshold, criterion='distance')

# Print the merged cluster labels for each data point
print("Merged Cluster Labels:", merged_clusters)

from collections import Counter

# Count the occurrences of each value
value_counts = Counter(merged_clusters)

# Print the unique values and their counts
for value, count in value_counts.items():
    print(f"{value}: {count}")

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.xlabel('Data Point')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram')
plt.show()
# Out:
# Merged Cluster Labels: [4 2 2 ... 2 2 2]
# 4: 603
# 2: 4492
# 1: 1221
# 3: 288

# %%
# define dictionary for distance measures
distance_measures = {'euclidean': 0, 'squared euclidean': 1, 'manhattan': 2, 'chebyshev': 3, 
                    'canberra': 5, 'chi-square': 6}
X = merged_clusters
y = y_km

# function defined to compute purity score using pyclustering for various distance measures
def pyPurity(dist_measure):
    pyLabels = X
    # function purity score is defined in previous section
    print(f"Rand-score for {dist_measure} is {round(metrics.rand_score(y, pyLabels)*100, 2)}%")
    print(f"Adj-Rand-score for {dist_measure} is {round(metrics.adjusted_rand_score(y, pyLabels)*100, 2)}%")
    print(f"Adj-Mutual-score for {dist_measure} is {round(metrics.adjusted_mutual_info_score(y, pyLabels)*100, 2)}%")
    print(f"Homogeneity-score for {dist_measure} is {round(metrics.homogeneity_score(y, pyLabels)*100, 2)}%")
    print(f"Completeness-score for {dist_measure} is {round(metrics.completeness_score(y, pyLabels)*100, 2)}%")
    print(f"V-measure-score for {dist_measure} is {round(metrics.v_measure_score(y, pyLabels)*100, 2)}%")
    print(f"Fowlkes-mallows-score for {dist_measure} is {round(metrics.fowlkes_mallows_score(y, pyLabels)*100, 2)}%")
    return purity_score(y, pyLabels)

# print results
for measure, value in distance_measures.items():
    print(f"The purity score for {measure} distance is {round(pyPurity(value)*100, 2)}%")
    print(" ")
# Out:
# Rand-score for 0 is 56.31%
# Adj-Rand-score for 0 is 13.13%
# Adj-Mutual-score for 0 is 28.3%
# Homogeneity-score for 0 is 24.46%
# Completeness-score for 0 is 33.71%
# V-measure-score for 0 is 28.35%
# Fowlkes-mallows-score for 0 is 47.15%
# The purity score for euclidean distance is 53.16%
#
# Rand-score for 1 is 56.31%
# Adj-Rand-score for 1 is 13.13%
# Adj-Mutual-score for 1 is 28.3%
# Homogeneity-score for 1 is 24.46%
# Completeness-score for 1 is 33.71%
# V-measure-score for 1 is 28.35%
# Fowlkes-mallows-score for 1 is 47.15%
# The purity score for squared euclidean distance is 53.16%
#
# Rand-score for 2 is 56.31%
# Adj-Rand-score for 2 is 13.13%
# Adj-Mutual-score for 2 is 28.3%
# Homogeneity-score for 2 is 24.46%
# Completeness-score for 2 is 33.71%
# V-measure-score for 2 is 28.35%
# Fowlkes-mallows-score for 2 is 47.15%
# The purity score for manhattan distance is 53.16%
#
# Rand-score for 3 is 56.31%
# Adj-Rand-score for 3 is 13.13%
# Adj-Mutual-score for 3 is 28.3%
# Homogeneity-score for 3 is 24.46%
# Completeness-score for 3 is 33.71%
# V-measure-score for 3 is 28.35%
# Fowlkes-mallows-score for 3 is 47.15%
# The purity score for chebyshev distance is 53.16%
#
# Rand-score for 5 is 56.31%
# Adj-Rand-score for 5 is 13.13%
# Adj-Mutual-score for 5 is 28.3%
# Homogeneity-score for 5 is 24.46%
# Completeness-score for 5 is 33.71%
# V-measure-score for 5 is 28.35%
# Fowlkes-mallows-score for 5 is 47.15%
# The purity score for canberra distance is 53.16%
#
# Rand-score for 6 is 56.31%
# Adj-Rand-score for 6 is 13.13%
# Adj-Mutual-score for 6 is 28.3%
# Homogeneity-score for 6 is 24.46%
# Completeness-score for 6 is 33.71%
# V-measure-score for 6 is 28.35%
# Fowlkes-mallows-score for 6 is 47.15%
# The purity score for chi-square distance is 53.16%
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
