# %% [markdown]
# Changing filenames in directory

# %%
import os

folder = 'D:\\PhD\\data\\test\\other\\'
count = 1
# count increase by 1 in each iteration
# iterate all files from a directory
for file_name in os.listdir(folder):
    # Construct old file name
    source = folder + file_name

    # Adding the count to the new file name and extension
    destination = folder + "other_" + str(count) + ".png"

    # Renaming the file
    os.rename(source, destination)
    count += 1
print('All Files Renamed')

print('New Names are')
# verify the result
res = os.listdir(folder)
print(res)
# Out:
# All Files Renamed
# New Names are
# ...

# %%
import os
import pandas as pd

os.chdir('D:\\PhD\\data\\test\\')

folders = ['anthrophony', 'biophony', 'geophony', 'other']

files = []

for folder in folders:
    for file in os.listdir(folder):
        files.append([file, folder])

pd.DataFrame(files, columns=['files', 'target']).to_csv('files_and_targets.csv')
