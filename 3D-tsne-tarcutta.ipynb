# %%
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
feature_vectors = pd.read_csv("39-feature-vector.csv")
labels_true = feature_vectors["class"]
feature_vectors = feature_vectors.drop(columns=["class"])
feature_vectors = feature_vectors.iloc[:, 0:13].values
labels_true
# Out:
# 0       anthrophony
# 1       anthrophony
# 2       anthrophony
# 3       anthrophony
# 4       anthrophony
#            ...
# 6599          other
# 6600          other
# 6601          other
# 6602          other
# 6603          other
# Name: class, Length: 6604, dtype: object

# %%
kmeans_data_old = pd.read_csv('kmeans_results.csv')

#encoding class values
kmeans_data_old['class'] = kmeans_data_old['class'].str.replace('other', str(0))
kmeans_data_old['class'] = kmeans_data_old['class'].str.replace('biophony', str(1))
kmeans_data_old['class'] = kmeans_data_old['class'].str.replace('geophony', str(2))
kmeans_data_old['class'] = kmeans_data_old['class'].str.replace('anthrophony', str(3))

y_km = kmeans_data_old['class']
# y_km.drop(y_km.tail(1).index, inplace=True)
y_km = y_km.values
y_km
# Out:
# array(['3', '3', '3', ..., '0', '0', '0'], dtype=object)

# %%
model = TSNE(n_components=3, learning_rate=150, perplexity=50, verbose=2, angle=0.1, random_state=0).fit_transform(feature_vectors)
# Out:
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\manifold\_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 6604 samples in 0.008s...
# [t-SNE] Computed neighbors for 6604 samples in 0.363s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 6604
# [t-SNE] Computed conditional probabilities for sample 2000 / 6604
# [t-SNE] Computed conditional probabilities for sample 3000 / 6604
# [t-SNE] Computed conditional probabilities for sample 4000 / 6604
# [t-SNE] Computed conditional probabilities for sample 5000 / 6604
# [t-SNE] Computed conditional probabilities for sample 6000 / 6604
# [t-SNE] Computed conditional probabilities for sample 6604 / 6604
# [t-SNE] Mean sigma: 0.051966
# [t-SNE] Computed conditional probabilities in 0.148s
# [t-SNE] Iteration 50: error = 85.7866516, gradient norm = 0.0083672 (50 iterations in 2.758s)
# [t-SNE] Iteration 100: error = 74.3051834, gradient norm = 0.0021364 (50 iterations in 2.442s)
# [t-SNE] Iteration 150: error = 73.7252731, gradient norm = 0.0004173 (50 iterations in 2.180s)
# [t-SNE] Iteration 200: error = 73.6403885, gradient norm = 0.0001902 (50 iterations in 2.296s)
# [t-SNE] Iteration 250: error = 73.6025772, gradient norm = 0.0001285 (50 iterations in 2.260s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.602577
# [t-SNE] Iteration 300: error = 1.8538456, gradient norm = 0.0007271 (50 iterations in 2.557s)
# [t-SNE] Iteration 350: error = 1.5079155, gradient norm = 0.0002286 (50 iterations in 3.134s)
# [t-SNE] Iteration 400: error = 1.3725893, gradient norm = 0.0001123 (50 iterations in 3.551s)
# [t-SNE] Iteration 450: error = 1.3005887, gradient norm = 0.0000657 (50 iterations in 3.384s)
# [t-SNE] Iteration 500: error = 1.2558639, gradient norm = 0.0000470 (50 iterations in 2.912s)
# [t-SNE] Iteration 550: error = 1.2260121, gradient norm = 0.0000334 (50 iterations in 3.110s)
# [t-SNE] Iteration 600: error = 1.2050080, gradient norm = 0.0000240 (50 iterations in 3.088s)
# [t-SNE] Iteration 650: error = 1.1896554, gradient norm = 0.0000188 (50 iterations in 3.083s)
# [t-SNE] Iteration 700: error = 1.1780705, gradient norm = 0.0000143 (50 iterations in 2.798s)
# [t-SNE] Iteration 750: error = 1.1689845, gradient norm = 0.0000113 (50 iterations in 2.926s)
# [t-SNE] Iteration 800: error = 1.1617270, gradient norm = 0.0000095 (50 iterations in 2.788s)
# [t-SNE] Iteration 850: error = 1.1557467, gradient norm = 0.0000096 (50 iterations in 2.902s)
# [t-SNE] Iteration 900: error = 1.1508614, gradient norm = 0.0000071 (50 iterations in 2.838s)
# [t-SNE] Iteration 950: error = 1.1468585, gradient norm = 0.0000065 (50 iterations in 2.839s)
# [t-SNE] Iteration 1000: error = 1.1435661, gradient norm = 0.0000067 (50 iterations in 2.902s)
# [t-SNE] KL divergence after 1000 iterations: 1.143566

# %%
colors = ['r', 'g', 'b', 'y']
y_int = [int(label) for label in y_km]
# Create 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(model[:, 0], model[:, 1], model[:, 2], c=[colors[label] for label in y_int])

# Set the viewing angle of the plot
ax.view_init(elev=20, azim=35)

# Allow interactive rotation of the plot
ax.set_box_aspect([1,1,1])
ax.mouse_init()

# Show plot
plt.title("3D t-SNE graph with ground truth values overlayed")
plt.show()

# %% [markdown]
# Silhouette analysis for 3 tsne components (8 is the best average)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score, silhouette_samples

X = model
# Define the range of cluster numbers to evaluate
min_clusters = 2
max_clusters = 12

# Initialize variables to store best cluster number and best silhouette score
best_n_clusters = None
best_score = -1

# Iterate over different cluster numbers and compute silhouette scores and plots
for n_clusters in range(min_clusters, max_clusters+1):
    # Fit KMeans clustering model with n_clusters
    kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(X)
    # Compute silhouette scores and plot
    fig, ax = plt.subplots()
    ax.set_xlim([-0.1, 1])
    ax.set_ylim([0, len(X) + (n_clusters + 1) * 10])
    silhouette_scores = silhouette_samples(X, kmeans.labels_)
    y_lower = 10
    for i in range(n_clusters):
        cluster_scores = silhouette_scores[kmeans.labels_ == i]
        cluster_scores.sort()
        size_cluster_i = len(cluster_scores)
        y_upper = y_lower + size_cluster_i
        color = plt.cm.nipy_spectral(float(i) / n_clusters)
        ax.fill_betweenx(np.arange(y_lower, y_upper), 0, cluster_scores, facecolor=color, alpha=0.7)
        ax.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
        y_lower = y_upper + 10
    ax.set_title("Silhouette plot for KMeans clustering with {} clusters".format(n_clusters))
    ax.set_xlabel("Silhouette coefficient values")
    ax.set_ylabel("Cluster labels")
    ax.axvline(x=silhouette_score(X, kmeans.labels_, metric='euclidean'), color="red", linestyle="--")
    ax.set_yticks([])
    plt.show()
# Out:
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Initialize an empty list to store SSE values
sse = []

# Fit KMeans algorithm on the dataset for k values from 1 to 10
for k in range(1, 12):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(model)
    sse.append(kmeans.inertia_)

# Plot SSE against k
sns.set_style("whitegrid")
plt.plot(range(1, 12), sse)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.show()
# Out:
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(
# c:\Users\Thomas\conda\envs\audiohandling\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=26.
#   warnings.warn(

# %%
import pandas as pd # dataframe manipulation
import numpy as np # linear algebra

# data visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# sklearn kmeans
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import contingency_matrix

# pyclustering kmeans
from pyclustering.cluster.kmeans import kmeans
from pyclustering.utils.metric import distance_metric
from pyclustering.cluster.center_initializer import random_center_initializer
from pyclustering.cluster.encoder import type_encoding
from pyclustering.cluster.encoder import cluster_encoder

from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_distances
from sklearn.metrics import adjusted_rand_score
from sklearn import metrics

# %%
from sklearn.cluster import AgglomerativeClustering

single_linkage = AgglomerativeClustering(n_clusters=6, affinity='euclidean', linkage='single')
labels_pred = single_linkage.fit_predict(model)
labels = single_linkage.labels_

# %%
def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    confusion_matrix = contingency_matrix(y_true, y_pred)
    # return purity
    return np.sum(np.amax(confusion_matrix, axis=0)) / np.sum(confusion_matrix)

# %%
print(purity_score(labels_true, labels_pred))
# Out:
# 0.3605390672319806

# %%
metrics.rand_score(labels_true, labels_pred)
# Out:
# 0.32131348625283024

# %%
metrics.adjusted_rand_score(labels_true, labels_pred)
# Out:
# -0.008616445812811012

# %%
metrics.adjusted_mutual_info_score(labels_true, labels_pred)
# Out:
# 0.05851531923479236

# %%
metrics.homogeneity_score(labels_true, labels_pred)
# Out:
# 0.034336732484989925

# %%
metrics.completeness_score(labels_true, labels_pred)
# Out:
# 0.24018409653621145

# %%
metrics.v_measure_score(labels_true, labels_pred)
# Out:
# 0.06008387122622274

# %%
metrics.fowlkes_mallows_score(labels_true, labels_pred)
# Out:
# 0.5140957760892724

# %%
# from sklearn.cluster import KMeans
# km = KMeans(n_clusters=8, init='k-means++', random_state=42)
# y_km = km.fit_predict(model)
# labels = km.labels_

# %%
labels
# Out:
# array([4, 4, 4, ..., 1, 1, 1], dtype=int64)

# %%
colors = ['r', 'g', 'b', 'y', 'rx', 'c', 'm', 'k', 'w']
y_int = [int(label) for label in labels]
# Create 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(model[:, 0], model[:, 1], model[:, 2], c=labels, cmap='viridis')

# Set the viewing angle of the plot
ax.view_init(elev=20, azim=35)

# Allow interactive rotation of the plot
ax.set_box_aspect([1,1,1])
ax.mouse_init()

# Show plot
plt.title("3D t-SNE graph with kmeans (k=8) overlayed")
plt.show()

# %%
import pandas as pd # dataframe manipulation
import numpy as np # linear algebra

# data visualization
import matplotlib.pyplot as plt
# %matplotlib inline
from yellowbrick.cluster import KElbowVisualizer # cluster visualizer

# sklearn kmeans
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import contingency_matrix

# pyclustering kmeans
from pyclustering.cluster.kmeans import kmeans
from pyclustering.utils.metric import distance_metric
from pyclustering.cluster.center_initializer import random_center_initializer
from pyclustering.cluster.encoder import type_encoding
from pyclustering.cluster.encoder import cluster_encoder

from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_distances
from sklearn.metrics import adjusted_rand_score
import numpy as np
import pandas as pd
from sklearn import metrics
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 7
#       5 import matplotlib.pyplot as plt
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 7 from yellowbrick.cluster import KElbowVisualizer # cluster visualizer
#       9 # sklearn kmeans
#      10 from sklearn.cluster import KMeans
#
# ModuleNotFoundError: No module named 'yellowbrick'

# %%
def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    confusion_matrix = contingency_matrix(y_true, y_pred)
    # return purity
    return np.sum(np.amax(confusion_matrix, axis=0)) / np.sum(confusion_matrix)

# %%
# define dictionary for distance measures
distance_measures = {'euclidean': 0, 'squared euclidean': 1, 'manhattan': 2, 'chebyshev': 3, 
                    'canberra': 5, 'chi-square': 6}
X = model
y = labels_true

# function defined to compute purity score using pyclustering for various distance measures
def pyPurity(dist_measure):
    initial_centers = random_center_initializer(X, 8, random_state=5).initialize()
    # instance created for respective distance metric
    instanceKm = kmeans(X, initial_centers=initial_centers, metric=distance_metric(dist_measure))
    # perform cluster analysis
    instanceKm.process()
    # cluster analysis results - clusters and centers
    pyClusters = instanceKm.get_clusters()
    pyCenters = instanceKm.get_centers()
    # enumerate encoding type to index labeling to get labels
    pyEncoding = instanceKm.get_cluster_encoding()
    pyEncoder = cluster_encoder(pyEncoding, pyClusters, X)
    pyLabels = pyEncoder.set_encoding(0).get_clusters()
    # function purity score is defined in previous section
    print(f"Rand-score for {dist_measure} is {round(metrics.rand_score(y, pyLabels)*100, 2)}%")
    print(f"Adj-Rand-score for {dist_measure} is {round(metrics.adjusted_rand_score(y, pyLabels)*100, 2)}%")
    print(f"Adj-Mutual-score for {dist_measure} is {round(metrics.adjusted_mutual_info_score(y, pyLabels)*100, 2)}%")
    print(f"Homogeneity-score for {dist_measure} is {round(metrics.homogeneity_score(y, pyLabels)*100, 2)}%")
    print(f"Completeness-score for {dist_measure} is {round(metrics.completeness_score(y, pyLabels)*100, 2)}%")
    print(f"V-measure-score for {dist_measure} is {round(metrics.v_measure_score(y, pyLabels)*100, 2)}%")
    print(f"Fowlkes-mallows-score for {dist_measure} is {round(metrics.fowlkes_mallows_score(y, pyLabels)*100, 2)}%")
    return purity_score(y, pyLabels)

# print results
for measure, value in distance_measures.items():
    print(f"The purity score for {measure} distance is {round(pyPurity(value)*100, 2)}%")
    print(" ")
# Out:
# Rand-score for 0 is 81.22%
# Adj-Rand-score for 0 is 47.19%
# Adj-Mutual-score for 0 is 60.18%
# Homogeneity-score for 0 is 76.5%
# Completeness-score for 0 is 49.65%
# V-measure-score for 0 is 60.22%
# Fowlkes-mallows-score for 0 is 60.97%
# The purity score for euclidean distance is 88.89%
#
# Rand-score for 1 is 81.22%
# Adj-Rand-score for 1 is 47.19%
# Adj-Mutual-score for 1 is 60.18%
# Homogeneity-score for 1 is 76.5%
# Completeness-score for 1 is 49.65%
# V-measure-score for 1 is 60.22%
# Fowlkes-mallows-score for 1 is 60.97%
# The purity score for squared euclidean distance is 88.89%
#
# Rand-score for 2 is 78.78%
# Adj-Rand-score for 2 is 38.98%
# Adj-Mutual-score for 2 is 57.79%
# Homogeneity-score for 2 is 75.27%
# Completeness-score for 2 is 46.95%
# V-measure-score for 2 is 57.83%
# Fowlkes-mallows-score for 2 is 54.17%
# The purity score for manhattan distance is 88.73%
#
# Rand-score for 3 is 80.43%
# Adj-Rand-score for 3 is 44.94%
# Adj-Mutual-score for 3 is 57.67%
# Homogeneity-score for 3 is 73.34%
# Completeness-score for 3 is 47.57%
# V-measure-score for 3 is 57.71%
# Fowlkes-mallows-score for 3 is 59.07%
# The purity score for chebyshev distance is 87.84%
#
# Rand-score for 5 is 75.99%
# Adj-Rand-score for 5 is 31.41%
# Adj-Mutual-score for 5 is 43.41%
# Homogeneity-score for 5 is 56.26%
# Completeness-score for 5 is 35.41%
# V-measure-score for 5 is 43.46%
# Fowlkes-mallows-score for 5 is 47.48%
# The purity score for canberra distance is 73.09%
#
# Rand-score for 6 is 80.54%
# Adj-Rand-score for 6 is 45.22%
# Adj-Mutual-score for 6 is 57.67%
# Homogeneity-score for 6 is 73.38%
# Completeness-score for 6 is 47.56%
# V-measure-score for 6 is 57.71%
# Fowlkes-mallows-score for 6 is 59.31%
# The purity score for chi-square distance is 87.43%

# %%
import numpy as np

# save the numpy array to a csv file
np.savetxt("tsne-3d.csv", model, delimiter=",", header="1, 2, 3")
